# %% [markdown]
# Below is the code for the coursera IBM data science specialization

# %%
#importing all relevant libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.cluster import KMeans
import matplotlib as mpl
import folium
import requests
import json 
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# using url and pandas for getting the dataframe
# using pandas to scrap the data from the wikipedia link and store it in data frame. Since the page has '3' tables/dataframe
# accessing the same using indexing
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df= pd.read_html(url, header = 0)
df = df[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %%
# Removing the rows having Borough values as Not assigned
# taking a look at the data also reveals that there are no neighbourhoods having 'not Assigned' after having cleaned the 'not assigned' borough 
df = df[df.Borough != 'Not assigned']
df.reset_index(drop = True, inplace = True)
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
#creating a dataframe from the given location data csv file. 
geodata = pd.read_csv('Geospatial_Coordinates.csv')
geodata.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#using pandas merge feature to match the column values for postal code and create the final required dataframe
finaldf = pd.merge(df, geodata, on = 'Postal Code',how = 'inner')

# %%
finaldf.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
torontomap = folium.Map(location = [43.6532,-79.3832], zoom_start = 10)
#superimposing neighnorhood data from our final dataset
for lat,lng,borough,neighborhood in zip(finaldf['Latitude'],finaldf['Longitude'],finaldf['Borough'],finaldf['Neighborhood']):
    label = '{},{}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(torontomap)
torontomap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ID = pd.read_csv('Book1.csv')

# %%
#defining Foursquare API credentials
CLIENT_ID = ID.loc[0,'CLIENT_ID']
CLIENT_SECRET = ID.loc[0,'CLIENT_SECRET']
VERSION = ID.loc[0,'VERSION']

# %%
#defining radius and limit
radius = 20000
LIMIT = 1000
latitude1 = 43.6534817 
longitude1 = -79.3839347

# %%
#defining query to Foursquare API
url1 = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId=4bf58dd8d48988d16d941735'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, radius, LIMIT)
results1 = requests.get(url1).json()
venue1= results1['response']['venues']
resultsdf1 =  pd.json_normalize(venue1)
resultsdf1
# Out:
#                           id                                    name  \
# 0   4ae60299f964a52003a421e3                               Starbucks
# 1   5d10db203e8ac400238e1bf1                               Starbucks
# 2   5a981dbe0c9f3129c9ee442c                               Starbucks
# 3   4b4626fef964a5204a1826e3                    Rooster Coffee House
# 4   5e5d749285a0610007e60fe8  Terroni Sud Forno Produzione e Spaccio
# 5   4ad79243f964a5204c0c21e3                          Jetfuel Coffee
# 6   5b4b6453c4404e001c1fa419                            Mofer Coffee
# 7   55ad1c45498ee54a96be5ba6                             Mattachioni
# 8   4ba3fa87f964a520d17338e3                          SanRemo Bakery
# 9   4b770853f964a5205d762ee3                               Starbucks
# 10  5a3aa18a5455b26eb31333d2                               Filosophy
# 11  4ad9c161f964a520a11a21e3                               Starbucks
# 12  4b26faaaf964a520aa8324e3                               Starbucks
# 13  551486ff498ee91ac6d40f43                               Starbucks
# 14  5bd738f4cd441c002c230068                               Starbucks
# 15  55fd4770498e7a8fbc9082fe                               Starbucks
# 16  4aec6bbaf964a520e6c621e3                               Starbucks
# 17  4bb3618514cfd13aa2ee15ab                      The Good Neighbour
# 18  4af746eef964a520ea0722e3                               Starbucks
# 19  4aec6b7df964a520e0c621e3                               Starbucks
# 20  5aaeba4e5a2c912c129564a5                               Starbucks
# 21  4be499ba8a8cb713cd4cc4a0                               Starbucks
# 22  4b8fca29f964a5206e6233e3                               Starbucks
# 23  4ade4a1af964a520ab7421e3                               Starbucks
# 24  4ae31b8ef964a520809021e3                               Starbucks
# 25  4b67686ff964a520084d2be3                               Starbucks
# 26  4ad8eb19f964a520f81521e3                               Starbucks
# 27  4b37b95df964a5200d4525e3                               Starbucks
# 28  4ae52541f964a5206aa021e3                               Starbucks
# 29  4adb58f7f964a520412621e3                         Balzac's Coffee
# 30  4ad8888ff964a520141221e3                               Starbucks
# 31  4bc5f529f360ef3be0ddda2d                               Starbucks
# 32  4b043657f964a5202c5222e3                               Starbucks
# 33  4e84e4017beb5b5d350e3e40                               Starbucks
# 34  5244b19111d24c95f862af2b                               Starbucks
# 35  5be2a490c876c80039857ee3                               Starbucks
# 36  4b9e85f1f964a5208beb36e3                              Second Cup
# 37  4bf968fb5efe2d7f2c286c34                                7-Eleven
# 38  58c7fbf7424f9373e6427e99                               Starbucks
# 39  4d9b165a7668f04d3869c993                               Starbucks
# 40  4ae0e2a7f964a5205f8321e3                               Starbucks
# 41  4af1e33df964a5201ee421e3                               Starbucks
# 42  4f64f614e4b0eae10ad6bf2d              Zaza Espresso Bar & Gelato
# 43  4b87eb6ff964a520e8d231e3                               Starbucks
# 44  524c6ea511d207bb0817c28e                Nespresso Boutique - Bar
# 45  4bbcb049593fef3bc4740256                             Arkady Cafe
# 46  4ad8bf7df964a5204c1421e3                               Starbucks
# 47  544bc764498eb6708774a72f                               Starbucks
# 48  4b981b46f964a520c22c35e3                               Starbucks
# 49  4ad4c05cf964a5200ff620e3                        Fresh On Spadina
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 1   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 2   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 3   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 4   [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...  v-1592654851    False
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 6   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 7   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 8   [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1592654851    False
# 9   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 10  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 11  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 12  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 13  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 14  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 15  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 16  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 17  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 18  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 19  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 20  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 21  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 22  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 23  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 24  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 25  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 26  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 27  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 28  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 29  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 30  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 31  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 32  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 33  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 34  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 35  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 36  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 37  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...  v-1592654851    False
# 38  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 39  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 40  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 41  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 42  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 43  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 44  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 45  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1592654851    False
# 46  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 47  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 48  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1592654851    False
# 49  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...  v-1592654851    False
#
#                                   location.address  \
# 0                     180 Queen St W, Suite 102.3A
# 1                           5650 Yonge St, Ste 101
# 2                             132 Queens Quay East
# 3                                479 Broadview Ave
# 4                                  22 Sackville St
# 5                               519 Parliament St.
# 6                              1040 St Clair Ave W
# 7                                  1617 Dupont St.
# 8                                374 Royal York Rd
# 9                               686 Bay St, Unit 3
# 10                                912 Bloor Street
# 11                               39 Eglinton Ave E
# 12                                5230 Dundas St W
# 13                        150 Park Lawn Rd, Unit A
# 14                               1100 Ellesmere Rd
# 15                               829 The Queensway
# 16                                   2630 Yonge St
# 17                                  238 Annette St
# 18  7080 Warden Ave, Bldg. B, Unit 6 Warden Centre
# 19                                 2451 Yonge St N
# 20                        3000 Highway 7 East, A14
# 21                                 201 Main Street
# 22                                   620 Jarvis St
# 23                                1020 Kingston Rd
# 24                          1005 King St W, Unit 7
# 25                             3900 Hwy 7, Unit #1
# 26                                1545 Bayview Ave
# 27                                3740 Midland Ave
# 28                                   1088 Yonge St
# 29                                1 Trinity Street
# 30                                   485 Church St
# 31                          2-1500 Bathurst Street
# 32                                  446 Spadina Rd
# 33           1 Beford Ave, One Bedford Condominium
# 34                                374 Evans Avenue
# 35                     1015 Sheppard Ave E, Unit 2
# 36                  4100 Living Arts Drive, Unit 2
# 37                                 883 Dundas St W
# 38                               351 King St E, 60
# 39                           43 Milner Ave, Unit 2
# 40         861 York Mills Rd, York Mills & Lesmill
# 41                      1250 Bay St, 100 The Maxus
# 42                               256 Beresford Ave
# 43                            3079-3081 Bloor St W
# 44                              159 Cumberland St.
# 45                                   3631 Dixie Rd
# 46                       2555 Victoria Park Avenue
# 47                1320 Castlefield Ave, Building D
# 48                                181 Bay St, Path
# 49                                147 Spadina Ave.
#
#               location.crossStreet  location.lat  location.lng  \
# 0                    at Simcoe St.     43.650751    -79.388047
# 1                              NaN     43.780178    -79.416408
# 2                              NaN     43.644489    -79.368639
# 3                 at Riverdale Ave     43.669177    -79.353134
# 4                              NaN     43.653903    -79.360018
# 5        btwn Carlton & Winchester     43.665295    -79.368335
# 6                              NaN     43.679094    -79.438931
# 7                              NaN     43.664960    -79.454912
# 8                   at Simpson Ave     43.618542    -79.499485
# 9                  at Gerrard St W     43.657656    -79.385007
# 10                             NaN     43.661879    -79.426471
# 11                        at Holly     43.706859    -79.396950
# 12             at Six Points Plaza     43.640187    -79.538053
# 13                   The Queensway     43.627931    -79.489286
# 14                             NaN     43.768181    -79.271665
# 15                  Taymall Avenue     43.624654    -79.508217
# 16               at Craighurst Ave     43.715590    -79.400450
# 17                  at Quebec Ave.     43.662578    -79.470986
# 18                at Steeles Ave E     43.822299    -79.325895
# 19                 at Erskine Ave.     43.711039    -79.398924
# 20                 Woodbine Avenue     43.850581    -79.357732
# 21   btwn Carlton Rd & HIghway 7 E     43.868473    -79.312043
# 22                    Bloor Street     43.671082    -79.380756
# 23                     Bingham Ave     43.680880    -79.284970
# 24                     at Shaw St.     43.641362    -79.414053
# 25                  Hwy 7 & Weston     43.789371    -79.553846
# 26                   at Belsize Dr     43.705190    -79.374760
# 27                 at McNicoll Ave     43.816201    -79.293314
# 28                at Roxborough St     43.678020    -79.390240
# 29               at Distillery Ln.     43.649797    -79.359142
# 30                 at Maitland St.     43.664980    -79.380510
# 31                 at Bathurst St.     43.683972    -79.418915
# 32                N of Lonsdale Rd     43.688970    -79.413097
# 33                  at Bloor St. W     43.668615    -79.397387
# 34                         Kipling     43.616190    -79.525714
# 35                             NaN     43.769700    -79.372830
# 36           at Princess Royal Dr.     43.588270    -79.645813
# 37        btwn Claremont & Manning     43.651023    -79.411077
# 38                             NaN     43.651613    -79.364917
# 39                   at McCowan Rd     43.783742    -79.253186
# 40                   at Lesmill Rd     43.754199    -79.351382
# 41               at Cumberland Ave     43.670627    -79.390337
# 42                   at Bloor St W     43.651106    -79.477710
# 43                    Thompson Ave     43.646597    -79.513914
# 44                   at Avenue Rd.     43.669883    -79.393359
# 45         Burnhamthorpe Road East     43.618794    -79.600325
# 46                 at Consumers Rd     43.773219    -79.321634
# 47                 at Caledonia Rd     43.699807    -79.461804
# 48  in Brookfield Place Food Court     43.647261    -79.378599
# 49              at Richmond St. W.     43.648048    -79.396008
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.650751, 'lng':...                449
# 1   [{'label': 'display', 'lat': 43.780178, 'lng':...              14343
# 2   [{'label': 'display', 'lat': 43.644489, 'lng':...               1587
# 3   [{'label': 'display', 'lat': 43.66917710774420...               3034
# 4   [{'label': 'display', 'lat': 43.653903, 'lng':...               1926
# 5   [{'label': 'display', 'lat': 43.66529519392083...               1818
# 6   [{'label': 'display', 'lat': 43.6790939, 'lng'...               5267
# 7   [{'label': 'display', 'lat': 43.66495951140892...               5857
# 8   [{'label': 'display', 'lat': 43.61854213652106...              10089
# 9   [{'label': 'display', 'lat': 43.657656, 'lng':...                472
# 10  [{'label': 'display', 'lat': 43.661879, 'lng':...               3550
# 11  [{'label': 'display', 'lat': 43.706859, 'lng':...               6033
# 12  [{'label': 'display', 'lat': 43.640187, 'lng':...              12502
# 13  [{'label': 'display', 'lat': 43.627931, 'lng':...               8950
# 14  [{'label': 'display', 'lat': 43.768181, 'lng':...              15640
# 15  [{'label': 'display', 'lat': 43.624654, 'lng':...              10514
# 16  [{'label': 'display', 'lat': 43.71559, 'lng': ...               7040
# 17  [{'label': 'display', 'lat': 43.66257807131982...               7083
# 18  [{'label': 'display', 'lat': 43.822299, 'lng':...              19363
# 19  [{'label': 'display', 'lat': 43.711039, 'lng':...               6519
# 20  [{'label': 'display', 'lat': 43.850581, 'lng':...              22041
# 21  [{'label': 'display', 'lat': 43.868473, 'lng':...              24620
# 22  [{'label': 'display', 'lat': 43.671082, 'lng':...               1975
# 23  [{'label': 'display', 'lat': 43.68088, 'lng': ...               8532
# 24  [{'label': 'display', 'lat': 43.641362, 'lng':...               2775
# 25  [{'label': 'display', 'lat': 43.789371, 'lng':...              20388
# 26  [{'label': 'display', 'lat': 43.70519, 'lng': ...               5803
# 27  [{'label': 'display', 'lat': 43.816201, 'lng':...              19525
# 28  [{'label': 'display', 'lat': 43.67802, 'lng': ...               2778
# 29  [{'label': 'display', 'lat': 43.64979714147618...               2038
# 30  [{'label': 'display', 'lat': 43.66498, 'lng': ...               1309
# 31  [{'label': 'display', 'lat': 43.68397177, 'lng...               4410
# 32  [{'label': 'display', 'lat': 43.68897, 'lng': ...               4595
# 33  [{'label': 'display', 'lat': 43.668615, 'lng':...               2002
# 34  [{'label': 'display', 'lat': 43.61619, 'lng': ...              12153
# 35  [{'label': 'display', 'lat': 43.7697, 'lng': -...              12968
# 36  [{'label': 'display', 'lat': 43.58826982840481...              22317
# 37  [{'label': 'display', 'lat': 43.6510231, 'lng'...               2203
# 38  [{'label': 'display', 'lat': 43.651613, 'lng':...               1545
# 39  [{'label': 'display', 'lat': 43.783742, 'lng':...              17914
# 40  [{'label': 'display', 'lat': 43.754199, 'lng':...              11513
# 41  [{'label': 'display', 'lat': 43.670627, 'lng':...               1977
# 42  [{'label': 'display', 'lat': 43.65110626640462...               7557
# 43  [{'label': 'display', 'lat': 43.646597, 'lng':...              10497
# 44  [{'label': 'display', 'lat': 43.66988316570838...               1977
# 45  [{'label': 'display', 'lat': 43.618794, 'lng':...              17856
# 46  [{'label': 'display', 'lat': 43.773219, 'lng':...              14240
# 47  [{'label': 'display', 'lat': 43.699807, 'lng':...               8117
# 48  [{'label': 'display', 'lat': 43.647261, 'lng':...                815
# 49  [{'label': 'display', 'lat': 43.64804820776361...               1145
#
#    location.postalCode location.cc location.city location.state  \
# 0              M5V 3X3          CA       Toronto             ON
# 1              M2M 4G3          CA       Toronto             ON
# 2              M5A 3Y5          CA       Toronto             ON
# 3              M4K 2N4          CA       Toronto             ON
# 4              M5A 3E2          CA       Toronto             ON
# 5              M4X 1P3          CA       Toronto             ON
# 6              M6E 1A5          CA       Toronto             ON
# 7              M6P 3S8          CA       Toronto             ON
# 8              M8Y 2R3          CA       Toronto             ON
# 9              M5G 0A4          CA       Toronto             ON
# 10             M6H 1L1          CA       Toronto             ON
# 11             M4P 1A2          CA       Toronto             ON
# 12             M9B 1A8          CA       Toronto             ON
# 13             M8Y 3H8          CA       Toronto             ON
# 14             M1P 2X3          CA       Toronto             ON
# 15             M8Z 1N6          CA       Toronto             ON
# 16             M4P 2J5          CA       Toronto             ON
# 17             M6P 1R1          CA       Toronto             ON
# 18             L3R 5Y2          CA       Markham             ON
# 19             M4P 2E7          CA       Toronto             ON
# 20             L3R 6E1          CA       Markham             ON
# 21             L3R 2G8          CA    Unionville             ON
# 22             M4Y 2H9          CA       Toronto             ON
# 23             M4E 1T4          CA       Toronto             ON
# 24             M6G 1B9          CA       Toronto             ON
# 25             L4H 1A6          CA    Woodbridge             ON
# 26             M4G 3B5          CA       Toronto             ON
# 27             M1V 4V3          CA       Toronto             ON
# 28             M4W 2L4          CA       Toronto             ON
# 29             M5A 3C4          CA       Toronto             ON
# 30             M4Y 2C6          CA       Toronto             ON
# 31             M5P 3L3          CA       Toronto             ON
# 32             M5P 3M2          CA       Toronto             ON
# 33             M5R 2J7          CA       Toronto             ON
# 34             M8Z 1K6          CA       Toronto             ON
# 35             M2K 1C2          CA       Toronto             ON
# 36             L5B 0C3          CA   Mississauga             ON
# 37             M6J 1V8          CA       Toronto             ON
# 38             M5A 1L1          CA       Toronto             ON
# 39             M1S 3P6          CA   Scarborough             ON
# 40             M3B 1Y2          CA    North York             ON
# 41             M5R 2B1          CA       Toronto             ON
# 42             M6S 3B4          CA       Toronto             ON
# 43             M8X 1C7          CA       Toronto             ON
# 44             M5R 1A2          CA       Toronto             ON
# 45             L4Y 4H4          CA   Mississauga             ON
# 46             M1T 1A3          CA       Toronto             ON
# 47             M6B 4B3          CA       Toronto             ON
# 48             M5J 2T3          CA       Toronto             ON
# 49             M5V 2L7          CA       Toronto             ON
#
#    location.country                          location.formattedAddress  \
# 0            Canada  [180 Queen St W, Suite 102.3A (at Simcoe St.),...
# 1            Canada  [5650 Yonge St, Ste 101, Toronto ON M2M 4G3, C...
# 2            Canada  [132 Queens Quay East, Toronto ON M5A 3Y5, Can...
# 3            Canada  [479 Broadview Ave (at Riverdale Ave), Toronto...
# 4            Canada      [22 Sackville St, Toronto ON M5A 3E2, Canada]
# 5            Canada  [519 Parliament St. (btwn Carlton & Winchester...
# 6            Canada  [1040 St Clair Ave W, Toronto ON M6E 1A5, Canada]
# 7            Canada      [1617 Dupont St., Toronto ON M6P 3S8, Canada]
# 8            Canada  [374 Royal York Rd (at Simpson Ave), Toronto O...
# 9            Canada  [686 Bay St, Unit 3 (at Gerrard St W), Toronto...
# 10           Canada     [912 Bloor Street, Toronto ON M6H 1L1, Canada]
# 11           Canada  [39 Eglinton Ave E (at Holly), Toronto ON M4P ...
# 12           Canada  [5230 Dundas St W (at Six Points Plaza), Toron...
# 13           Canada  [150 Park Lawn Rd, Unit A (The Queensway), Tor...
# 14           Canada    [1100 Ellesmere Rd, Toronto ON M1P 2X3, Canada]
# 15           Canada  [829 The Queensway (Taymall Avenue), Toronto O...
# 16           Canada  [2630 Yonge St (at Craighurst Ave), Toronto ON...
# 17           Canada  [238 Annette St (at Quebec Ave.), Toronto ON M...
# 18           Canada  [7080 Warden Ave, Bldg. B, Unit 6 Warden Centr...
# 19           Canada  [2451 Yonge St N (at Erskine Ave.), Toronto ON...
# 20           Canada  [3000 Highway 7 East, A14 (Woodbine Avenue), M...
# 21           Canada  [201 Main Street (btwn Carlton Rd & HIghway 7 ...
# 22           Canada  [620 Jarvis St (Bloor Street), Toronto ON M4Y ...
# 23           Canada  [1020 Kingston Rd (Bingham Ave), Toronto ON M4...
# 24           Canada  [1005 King St W, Unit 7 (at Shaw St.), Toronto...
# 25           Canada  [3900 Hwy 7, Unit #1 (Hwy 7 & Weston), Woodbri...
# 26           Canada  [1545 Bayview Ave (at Belsize Dr), Toronto ON ...
# 27           Canada  [3740 Midland Ave (at McNicoll Ave), Toronto O...
# 28           Canada  [1088 Yonge St (at Roxborough St), Toronto ON ...
# 29           Canada  [1 Trinity Street (at Distillery Ln.), Toronto...
# 30           Canada  [485 Church St (at Maitland St.), Toronto ON M...
# 31           Canada  [2-1500 Bathurst Street (at Bathurst St.), Tor...
# 32           Canada  [446 Spadina Rd (N of Lonsdale Rd), Toronto ON...
# 33           Canada  [1 Beford Ave, One Bedford Condominium (at Blo...
# 34           Canada  [374 Evans Avenue (Kipling), Toronto ON M8Z 1K...
# 35           Canada  [1015 Sheppard Ave E, Unit 2, Toronto ON M2K 1...
# 36           Canada  [4100 Living Arts Drive, Unit 2 (at Princess R...
# 37           Canada  [883 Dundas St W (btwn Claremont & Manning), T...
# 38           Canada    [351 King St E, 60, Toronto ON M5A 1L1, Canada]
# 39           Canada  [43 Milner Ave, Unit 2 (at McCowan Rd), Scarbo...
# 40           Canada  [861 York Mills Rd, York Mills & Lesmill (at L...
# 41           Canada  [1250 Bay St, 100 The Maxus (at Cumberland Ave...
# 42           Canada  [256 Beresford Ave (at Bloor St W), Toronto ON...
# 43           Canada  [3079-3081 Bloor St W (Thompson Ave), Toronto ...
# 44           Canada  [159 Cumberland St. (at Avenue Rd.), Toronto O...
# 45           Canada  [3631 Dixie Rd (Burnhamthorpe Road East), Miss...
# 46           Canada  [2555 Victoria Park Avenue (at Consumers Rd), ...
# 47           Canada  [1320 Castlefield Ave, Building D (at Caledoni...
# 48           Canada  [181 Bay St, Path (in Brookfield Place Food Co...
# 49           Canada  [147 Spadina Ave. (at Richmond St. W.), Toront...
#
#              location.neighborhood
# 0                              NaN
# 1                       Willowdale
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7   Junction Triangle, Toronto, ON
# 8                              NaN
# 9               Discovery District
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13           Stonegate - Queensway
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                          High P
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# 40                             NaN
# 41                             NaN
# 42                             NaN
# 43                             NaN
# 44                             NaN
# 45                             NaN
# 46                             NaN
# 47                             NaN
# 48                             NaN
# 49                             NaN

# %%
resultsdf1.shape
# Out:
# (50, 18)

# %%
#defining a new dataframe using only the required columns
resultsdf_new = resultsdf1[['location.lat','location.lng','location.distance']]

# %%
resultsdf_new.shape
# Out:
# (50, 3)

# %%
#defining the K means algorithm
k = 6
kmeans = KMeans(init = "k-means++", n_clusters = k, n_init = 12).fit(resultsdf_new)

# %%
kmeans.labels_
# Out:
# array([0, 5, 0, 0, 0, 0, 4, 4, 2, 0, 0, 4, 5, 2, 5, 2, 4, 4, 1, 4, 3, 3,
#        0, 2, 0, 1, 4, 1, 0, 0, 0, 4, 4, 0, 5, 5, 3, 0, 0, 1, 2, 0, 4, 2,
#        0, 1, 5, 2, 0, 0])

# %%
resultsdf_new.insert(0, 'Cluster_labels', kmeans.labels_)
resultsdf_new.head()
# Out:
#    Cluster_labels  location.lat  location.lng  location.distance
# 0               0     43.650751    -79.388047                449
# 1               5     43.780178    -79.416408              14343
# 2               0     43.644489    -79.368639               1587
# 3               0     43.669177    -79.353134               3034
# 4               0     43.653903    -79.360018               1926

# %%
#plotting the K means results using Folium
map_clusters = folium.Map(location = (latitude1, longitude1), zoom_start = 11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, cluster in zip(resultsdf_new['location.lat'], resultsdf_new['location.lng'], resultsdf_new['Cluster_labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
